# %%
import torch
expected_outputs = torch.load("sanity_check.pt")

# %%
expected_outputs["o_t"]
# Out:
# tensor([[ 0.6525, -0.1904,  0.1833, -0.1120],
#         [-0.0000, -0.0247,  0.1138, -0.3553]])
